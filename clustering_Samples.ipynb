# %%
pip install scikit-learn
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install scikit-learn
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
# check scikit-learn version
import sklearn
print(sklearn.__version__)
# Out:
# 0.22.2.post1

# %%
a = []
while(1):
  a.append('1')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-fe4ce4957d1f> in <module>()
#       1 a = []
#       2 while(1):
# ----> 3   a.append('1')
#
# KeyboardInterrupt:

# %% [markdown]
# # ** Clustering Dataset **

# %%
from datetime import datetime

# %%
# synthetic classification dataset
from numpy import where
from sklearn.datasets import make_classification
from matplotlib import pyplot
# define dataset
X100k, y100k = make_classification(n_samples=10000, n_features=50, n_informative=25, n_redundant=0, n_clusters_per_class=2, random_state=40)
# create scatter plot for samples from each class
for class_value in range(10):
	# get row indexes for samples with this class
	row_ix = where(y100k == class_value)
	# create scatter of these samples
	pyplot.scatter(X100k[row_ix, 0], X100k[row_ix, 1], X100k[row_ix, 2])
# show the plot
pyplot.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/collections.py:886: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# Affinity Propagation

# %%
# affinity propagation clustering
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import AffinityPropagation
from matplotlib import pyplot

# %%
# define dataset
X50k, y50k = make_classification(n_samples=50000, n_features=50, n_informative=25, n_redundant=0, n_clusters_per_class=2, random_state=40)

# %%
X
# Out:
# array([[ 0.36943778,  2.07075605, -2.7807926 , ...,  0.14667919,
#         -0.12060684,  5.4397785 ],
#        [-1.19811762,  0.22859281,  0.65983343, ..., -2.58383713,
#         -0.52992184,  4.28643121],
#        [ 0.13567892,  3.33717466, -1.6117895 , ..., -0.30520454,
#          1.82334461, -0.04393945],
#        ...,
#        [-0.3456083 ,  0.11231243, -0.20877402, ...,  0.44931374,
#         -1.30697974,  1.98794903],
#        [ 0.94751673,  3.68843506, -0.18250475, ..., -0.41241115,
#         -0.81776508, -6.81430009],
#        [ 1.53230737,  2.18919139,  0.60079573, ..., -0.4314261 ,
#         -0.73673332,  4.08118498]])

# %%
now = datetime.now()
# define the model
model = AffinityPropagation(damping=0.9)
# fit the model
model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
end = datetime.now()
print('Process ended in', end - now )
# Out:
# Process ended in 0:05:55.629542
# /usr/local/lib/python3.6/dist-packages/sklearn/cluster/_affinity_propagation.py:226: ConvergenceWarning: Affinity propagation did not converge, this model will not have any cluster centers.
#   "will not have any cluster centers.", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/cluster/_affinity_propagation.py:423: ConvergenceWarning: This model does not have any cluster centers because affinity propagation did not converge. Labeling every sample as '-1'.
#   "Labeling every sample as '-1'.", ConvergenceWarning)

# %%
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %%
len(model.labels_)
# Out:
# 10000

# %%
# define dataset
X1, _ = make_classification(n_samples=50000, n_features=50, n_informative=25, n_redundant=0, n_clusters_per_class=2, random_state=40)

# %% [markdown]
# Agglomerative Clustering
#
# 50k satır datayla, daha az memory kullanarak çalışabildi. 25gb ram limitli.

# %%
# agglomerative clustering
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import AgglomerativeClustering
from matplotlib import pyplot

# %%
now = datetime.now()
# define the model
model = AgglomerativeClustering(n_clusters=20)
# fit model and predict clusters
yhat = model.fit_predict(X1)
end = datetime.now()
print('Process ended in', end - now )
# Out:
# Process ended in 0:03:44.181013

# %%
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(X1[row_ix, 0], X1[row_ix, 1], X1[row_ix, 2])
# show the plot
pyplot.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/collections.py:886: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# BIRCH
#
# 50k satır datayla 20 cluster, daha az memory kullanarak çalışabildi. 25gb ram limitli.

# %%
# birch clustering
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import Birch
from matplotlib import pyplot

# %%
now = datetime.now()
# define the model
model = Birch(threshold=0.01, n_clusters=20)
# fit the model
model.fit(X1)
# assign a cluster to each example
yhat = model.predict(X1)
end = datetime.now()
print('Process ended in', end - now )
# Out:
# Process ended in 0:03:59.054172

# %%
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(X1[row_ix, 0], X1[row_ix, 1], X1[row_ix, 2])
# show the plot
pyplot.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/collections.py:886: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# DBSCAN
#
# Çok hızlı.
#
#
# 50k satır datayla 20 cluster, daha az memory kullanarak çalışabildi. 25gb ram limitli.
#
# https://saskeli.github.io/data-analysis-with-python-summer-2019/clustering.html

# %%
# dbscan clustering
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from matplotlib import pyplot

# %%
now = datetime.now()
# define the model
model = DBSCAN(eps=0.30, min_samples=9)
# fit model and predict clusters
yhat = model.fit_predict(X1)
end = datetime.now()
print('Process ended in', end - now )
# Out:
# Process ended in 0:00:02.816171

# %%
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(X1[row_ix, 0], X1[row_ix, 1], X1[row_ix, 2], X1[row_ix, 3])
# show the plot
pyplot.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/collections.py:886: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# HDBSCAN
#
# Çok hızlı.
#
#
# 50k satır datayla , daha az memory kullanarak çalışabildi. 25gb ram limitli.

# %%
# !pip install hdbscan
# Out:
# ...
#      |████████████████████████████████| 4.7MB 1.4MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for hdbscan: filename=hdbscan-0.8.26-cp36-cp36m-linux_x86_64.whl size=2361225 sha256=a227444574c90c47583344901c2e0c16d99508ba2cbc9a2671031cc8b461c338
#   Stored in directory: /root/.cache/pip/wheels/82/38/41/372f034d8abd271ef7787a681e0a47fc05d472683a7eb088ed
# Successfully built hdbscan
# ...

# %%
import hdbscan

# %%
now = datetime.now()
# %time clusterer = hdbscan.HDBSCAN(algorithm='best', allow_single_cluster=False, alpha=1.0, approx_min_span_tree=True, cluster_selection_epsilon=0.0, cluster_selection_method='eom', core_dist_n_jobs=-1, gen_min_span_tree=False, leaf_size=40, match_reference_implementation=False, metric='euclidean', min_cluster_size=100, min_samples=25, p=None, prediction_data=False)
# %time yhat = clusterer.fit(X1)
end = datetime.now()
print('Process ended in', end - now )
# Out:
# CPU times: user 31 µs, sys: 0 ns, total: 31 µs
# Wall time: 35.5 µs
# CPU times: user 6.98 s, sys: 169 ms, total: 7.15 s
# Wall time: 1min 8s
# Process ended in 0:01:08.453074

# %%
unique(yhat)
# Out:
# array([HDBSCAN(algorithm='best', allow_single_cluster=False, alpha=1.0,
#         approx_min_span_tree=True, cluster_selection_epsilon=0.0,
#         cluster_selection_method='eom', core_dist_n_jobs=-1,
#         gen_min_span_tree=False, leaf_size=40,
#         match_reference_implementation=False, memory=Memory(location=None),
#         metric='euclidean', min_cluster_size=100, min_samples=25, p=None,
#         prediction_data=False)], dtype=object)

# %%
# retrieve unique clusters
hdbscan_clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in hdbscan_clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    print(cluster)
    print(row_ix)
    # create scatter of these samples
    pyplot.scatter(X1[row_ix, 0], X1[row_ix, 1])#, X1[row_ix, 2], X1[row_ix, 3])
# show the plot
pyplot.show()
# Out:
# HDBSCAN(algorithm='best', allow_single_cluster=False, alpha=1.0,
#         approx_min_span_tree=True, cluster_selection_epsilon=0.0,
#         cluster_selection_method='eom', core_dist_n_jobs=-1,
#         gen_min_span_tree=False, leaf_size=40,
#         match_reference_implementation=False, memory=Memory(location=None),
#         metric='euclidean', min_cluster_size=100, min_samples=25, p=None,
#         prediction_data=False)
# (array([0]),)

# %% [markdown]
# K-Means
#
# Çok hızlı.
#
#
# 1M satır datayla 20 cluster, daha az memory kullanarak çalışabildi. 25gb ram limitli.

# %%
# k-means clustering
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import KMeans
from matplotlib import pyplot

# %%
# define dataset
X1m, y1m = make_classification(n_samples=100000, n_features=50, n_informative=25, n_redundant=0, n_clusters_per_class=2, random_state=40)

# %%
# define dataset
X10k, y10k = make_classification(n_samples=10000, n_features=50, n_informative=25, n_redundant=0, n_clusters_per_class=2, random_state=40)

# %%
now = datetime.now()
# define the model
model = KMeans(n_clusters=20)
# fit the model
model.fit(X2)
end = datetime.now()
print('Process ended in', end - now )
# Out:
# Process ended in 0:01:01.663983

# %%
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    #pyplot.scatter(X2[row_ix, 0], X2[row_ix, 1],X2[row_ix, 2])
    pyplot.scatter(X2[:,0],X2[:,1] ,X2[:,2], c=model.labels_);
    pyplot.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=100, color="red"); # Show the centres
# show the plot
pyplot.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/collections.py:886: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
pyplot.scatter(X2[:,0],X2[:,1] ,X2[:,2], c=model.labels_);
pyplot.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=100, color="red"); # Show the centres
# show the plot
pyplot.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/collections.py:886: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
model.cluster_centers_.max(), len(model.cluster_centers_)
# Out:
# (4.578561441337164, 20)

# %% [markdown]
# Mini-Batch
#
#
# K-Means'den 30 kat daha hızlı.
#
# 1M satır datayla 20 cluster, daha az memory kullanarak çalışabildi. 25gb ram limitli.

# %%
# mini-batch k-means clustering
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import MiniBatchKMeans
from matplotlib import pyplot

# %%
now = datetime.now()
# define the model
model2 = MiniBatchKMeans(n_clusters=20)
# fit the model
model2.fit(X2)
# assign a cluster to each example
yhat2 = model2.predict(X2)
end = datetime.now()
print('Process ended in', end - now )
# Out:
# Process ended in 0:00:02.211397

# %%
# retrieve unique clusters
clusters2 = unique(yhat2)
# create scatter plot for samples from each cluster
for cluster2 in clusters2:
    # get row indexes for samples with this cluster
    row_ix2 = where(yhat == cluster2)
    # create scatter of these samples
    #pyplot.scatter(X[row_ix, 0], X[row_ix, 1],X[row_ix, 2])
    pyplot.scatter(X2[:,0],X2[:,1] ,X2[:,2], c=model2.labels_);
    pyplot.scatter(model2.cluster_centers_[:,0], model2.cluster_centers_[:,1], s=100, color="red"); # Show the centres
# show the plot
pyplot.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/collections.py:886: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# Mean Shift

# %%
# mean shift clustering
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import MeanShift
from matplotlib import pyplot

# %%
now = datetime.now()
model = MeanShift()
# fit model and predict clusters
yhat = model.fit_predict(X)

end = datetime.now()
print('Process ended in', end - now )
# Out:
# Process ended in 0:02:47.188251

# %%
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    #pyplot.scatter(X[row_ix, 0], X[row_ix, 1],X[row_ix, 2], X[row_ix, 3])
    pyplot.scatter(X[:,0],X[:,1] ,X[:,2], c=model.labels_);
    pyplot.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=100, color="red"); # Show the centres

# show the plot
pyplot.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/collections.py:886: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# OPTICS

# %%
# optics clustering
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import OPTICS
from matplotlib import pyplot

# %%
now = datetime.now()
# define the model
model = OPTICS(eps=0.8, min_samples=10)
# fit model and predict clusters
yhat = model.fit_predict(X10k)
end = datetime.now()
print('Process ended in', end - now )
# Out:
# Process ended in 0:00:58.478986

# %%
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	#pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
  pyplot.scatter(X10k[:,0],X10k[:,1] ,X10k[:,2], c=model.labels_)
  pyplot.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=100, color="red") # Show the centres
# show the plot
pyplot.show()
# Out:
#   File "<ipython-input-10-571fdc9bbeb1>", line 8
#     pyplot.scatter(X10k[:,0],X10k[:,1] ,X10k[:,2], c=model.labels_);
#                                                                     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# Spectral Clustering

# %%
# spectral clustering
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot

# %%
now = datetime.now()
# define the model
model = SpectralClustering(n_clusters=20)
# fit model and predict clusters
yhat = model.fit_predict(X10k)
end = datetime.now()
print('Process ended in', end - now )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-50da3db84af6> in <module>()
#       3 model = SpectralClustering(n_clusters=20)
#       4 # fit model and predict clusters
# ----> 5 yhat = model.fit_predict(X10k)
#       6 end = datetime.now()
#       7 print('Process ended in', end - now )
#
# /usr/local/lib/python3.6/dist-packages/sklearn/cluster/_spectral.py in fit_predict(self, X, y)
#     543             Cluster labels.
#     544         """
# --> 545         return super().fit_predict(X, y)
#     546
#     547     @property
#
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py in fit_predict(self, X, y)
#     460         # non-optimized default implementation; override when a better
#     461         # method is possible for a given clustering algorithm
# --> 462         self.fit(X)
#     463         return self.labels_
#     464
#
# ...

# %%
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	#pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
  pyplot.scatter(X10k[:,0],X10k[:,1] ,X10k[:,2], c=model.labels_);
  pyplot.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=100, color="red"); # Show the centres
# show the plot
pyplot.show()

# %% [markdown]
# Gaussian Mixture Model

# %%
# gaussian mixture clustering
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.mixture import GaussianMixture
from matplotlib import pyplot

# %%
now = datetime.now()
# define the model
model = GaussianMixture(n_components=20)
# fit the model
model.fit(X10k)
# assign a cluster to each example
yhat = model.predict(X10k)
end = datetime.now()
print('Process ended in', end - now )
# Out:
# Process ended in 0:00:14.969763

# %%
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X10k[row_ix, 0], X10k[row_ix, 1], X10k[row_ix, 3])
  #pyplot.scatter(X10k[:,0],X10k[:,1] ,X10k[:,2])#, c=model.labels_);
  #pyplot.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=100, color="red");# Show the centres
# show the plot
pyplot.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/collections.py:886: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
